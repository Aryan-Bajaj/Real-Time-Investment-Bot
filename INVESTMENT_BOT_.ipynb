# %%
pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import yfinance as yf
import math
import pandas_datareader as web
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential #layer by layer
from keras.layers import Dense, LSTM # Dense - helps in carrying neurons from one layer to another  # LSTM - Recurrent Neural Networks and it has loops to think from scratch

# %%
stock_1 = "AXISBANK.BO"
Stock_1 = yf.Ticker(stock_1)
hist = Stock_1.history(period="10mo")
data = hist.filter(['Close'])
dataset=data.values
new_df = hist.filter(['Close'])
last_60_days = new_df[-60:].values
training = math.ceil(len(dataset) * 0.7)
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
train_data = scaled_data[0:training,:]
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1],1))
x_train.shape
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (x_train.shape[1],1)))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train, y_train, batch_size = 1, epochs = 10)
last_60_days_scaled = scaler.transform(last_60_days)
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
pred_price_1 = model.predict(X_test)
pred_price_1 = scaler.inverse_transform(pred_price_1)

diff_1=pred_price_1-Stock_1.info['currentPrice']

earned_1 = ((1000 - Stock_1.info['currentPrice'])+pred_price_1)
# Out:
# Epoch 1/10
# 87/87 [==============================] - 7s 33ms/step - loss: 0.0437
# Epoch 2/10
# 87/87 [==============================] - 4s 51ms/step - loss: 0.0213
# Epoch 3/10
# 87/87 [==============================] - 5s 54ms/step - loss: 0.0164
# Epoch 4/10
# 87/87 [==============================] - 4s 50ms/step - loss: 0.0141
# Epoch 5/10
# 87/87 [==============================] - 5s 54ms/step - loss: 0.0109
# Epoch 6/10
# 87/87 [==============================] - 4s 50ms/step - loss: 0.0098
# Epoch 7/10
# 87/87 [==============================] - 4s 49ms/step - loss: 0.0114
# Epoch 8/10
# 87/87 [==============================] - 4s 45ms/step - loss: 0.0082
# Epoch 9/10
# 87/87 [==============================] - 2s 28ms/step - loss: 0.0086
# Epoch 10/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0080

# %%
stock_2 = "INDUSINDBK.BO"
Stock_2 = yf.Ticker(stock_2)
hist = Stock_2.history(period="10mo")
data = hist.filter(['Close'])
dataset=data.values
new_df = hist.filter(['Close'])
last_60_days = new_df[-60:].values
training = math.ceil(len(dataset) * 0.7)
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
train_data = scaled_data[0:training,:]
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1],1))
x_train.shape
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (x_train.shape[1],1)))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train, y_train, batch_size = 1, epochs = 10)
last_60_days_scaled = scaler.transform(last_60_days)
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
pred_price_2 = model.predict(X_test)
pred_price_2 = scaler.inverse_transform(pred_price_2)

diff_2=pred_price_2-Stock_2.info['currentPrice']

earned_2 = ((1000 - Stock_2.info['currentPrice'])+pred_price_2)
# Out:
# Epoch 1/10
# 87/87 [==============================] - 6s 28ms/step - loss: 0.0147
# Epoch 2/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0075
# Epoch 3/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0059
# Epoch 4/10
# 87/87 [==============================] - 2s 29ms/step - loss: 0.0046
# Epoch 5/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0048
# Epoch 6/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0044
# Epoch 7/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0040
# Epoch 8/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0042
# Epoch 9/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0033
# Epoch 10/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0032

# %%
stock_3 = "SAKSOFT.BO"
Stock_3 = yf.Ticker(stock_3)
hist = Stock_3.history(period="10mo")
data = hist.filter(['Close'])
dataset=data.values
new_df = hist.filter(['Close'])
last_60_days = new_df[-60:].values
training = math.ceil(len(dataset) * 0.7)
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
train_data = scaled_data[0:training,:]
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1],1))
x_train.shape
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (x_train.shape[1],1)))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train, y_train, batch_size = 1, epochs = 10)
last_60_days_scaled = scaler.transform(last_60_days)
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
pred_price_3 = model.predict(X_test)
pred_price_3 = scaler.inverse_transform(pred_price_3)

diff_3=pred_price_3-Stock_3.info['currentPrice']

earned_3 = ((1000 - Stock_3.info['currentPrice'])+pred_price_3)
# Out:
# Epoch 1/10
# 87/87 [==============================] - 6s 30ms/step - loss: 0.0326
# Epoch 2/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0230
# Epoch 3/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0168
# Epoch 4/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0153
# Epoch 5/10
# 87/87 [==============================] - 4s 41ms/step - loss: 0.0142
# Epoch 6/10
# 87/87 [==============================] - 5s 54ms/step - loss: 0.0127
# Epoch 7/10
# 87/87 [==============================] - 4s 51ms/step - loss: 0.0135
# Epoch 8/10
# 87/87 [==============================] - 5s 53ms/step - loss: 0.0113
# Epoch 9/10
# 87/87 [==============================] - 4s 50ms/step - loss: 0.0102
# Epoch 10/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0110

# %%
stock_4 = "WIPRO.BO"
Stock_4 = yf.Ticker(stock_4)
hist = Stock_4.history(period="10mo")
data = hist.filter(['Close'])
dataset=data.values
new_df = hist.filter(['Close'])
last_60_days = new_df[-60:].values
training = math.ceil(len(dataset) * 0.7)
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
train_data = scaled_data[0:training,:]
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1],1))
x_train.shape
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (x_train.shape[1],1)))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train, y_train, batch_size = 1, epochs = 10)
last_60_days_scaled = scaler.transform(last_60_days)
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
pred_price_4 = model.predict(X_test)
pred_price_4 = scaler.inverse_transform(pred_price_4)

diff_4=pred_price_4-Stock_4.info['currentPrice']

earned_4 = ((1000 - Stock_4.info['currentPrice'])+pred_price_4)
# Out:
# Epoch 1/10
# 87/87 [==============================] - 6s 30ms/step - loss: 0.0307
# Epoch 2/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0108
# Epoch 3/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0099
# Epoch 4/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0058
# Epoch 5/10
# 87/87 [==============================] - 3s 35ms/step - loss: 0.0034
# Epoch 6/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0034
# Epoch 7/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0033
# Epoch 8/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0026
# Epoch 9/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0032
# Epoch 10/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0042

# %%
stock_5 = "DHUNINV.BO"
Stock_5 = yf.Ticker(stock_5)
hist = Stock_5.history(period="10mo")
data = hist.filter(['Close'])
dataset=data.values
new_df = hist.filter(['Close'])
last_60_days = new_df[-60:].values
training = math.ceil(len(dataset) * 0.7)
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
train_data = scaled_data[0:training,:]
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1],1))
x_train.shape
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (x_train.shape[1],1)))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train, y_train, batch_size = 1, epochs = 10)
last_60_days_scaled = scaler.transform(last_60_days)
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
pred_price_5 = model.predict(X_test)
pred_price_5 = scaler.inverse_transform(pred_price_5)

diff_5=pred_price_5-Stock_5.info['currentPrice']

earned_5 = ((1000 - Stock_5.info['currentPrice'])+pred_price_5)
# Out:
# Epoch 1/10
# 87/87 [==============================] - 6s 30ms/step - loss: 0.0457
# Epoch 2/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0290
# Epoch 3/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0220
# Epoch 4/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0235
# Epoch 5/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0210
# Epoch 6/10
# 87/87 [==============================] - 3s 31ms/step - loss: 0.0187
# Epoch 7/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0169
# Epoch 8/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0174
# Epoch 9/10
# 87/87 [==============================] - 3s 31ms/step - loss: 0.0149
# Epoch 10/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0152
# ...

# %%
stock_6 = "APOLLOFI.BO"
Stock_6 = yf.Ticker(stock_6)
hist = Stock_6.history(period="10mo")
data = hist.filter(['Close'])
dataset=data.values
new_df = hist.filter(['Close'])
last_60_days = new_df[-60:].values
training = math.ceil(len(dataset) * 0.7)
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
train_data = scaled_data[0:training,:]
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1],1))
x_train.shape
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (x_train.shape[1],1)))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train, y_train, batch_size = 1, epochs = 10)
last_60_days_scaled = scaler.transform(last_60_days)
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
pred_price_6 = model.predict(X_test)
pred_price_6 = scaler.inverse_transform(pred_price_6)

diff_6=pred_price_6-Stock_6.info['currentPrice']

earned_6 = ((1000 - Stock_6.info['currentPrice'])+pred_price_6)
# Out:
# Epoch 1/10
# 87/87 [==============================] - 6s 30ms/step - loss: 0.0389
# Epoch 2/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0155
# Epoch 3/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0131
# Epoch 4/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0123
# Epoch 5/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0115
# Epoch 6/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0085
# Epoch 7/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0073
# Epoch 8/10
# 87/87 [==============================] - 3s 34ms/step - loss: 0.0073
# Epoch 9/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0062
# Epoch 10/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0061
# ...

# %%
stock_7 = "GODREJAGRO.BO"
Stock_7 = yf.Ticker(stock_7)
hist = Stock_7.history(period="10mo")
data = hist.filter(['Close'])
dataset=data.values
new_df = hist.filter(['Close'])
last_60_days = new_df[-60:].values
training = math.ceil(len(dataset) * 0.7)
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
train_data = scaled_data[0:training,:]
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1],1))
x_train.shape
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (x_train.shape[1],1)))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train, y_train, batch_size = 1, epochs = 10)
last_60_days_scaled = scaler.transform(last_60_days)
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
pred_price_7 = model.predict(X_test)
pred_price_7 = scaler.inverse_transform(pred_price_7)

diff_7=pred_price_7-Stock_7.info['currentPrice']

earned_7 = ((1000 - Stock_7.info['currentPrice'])+pred_price_7)
# Out:
# Epoch 1/10
# 87/87 [==============================] - 6s 30ms/step - loss: 0.0141
# Epoch 2/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0127
# Epoch 3/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0123
# Epoch 4/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0111
# Epoch 5/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0118
# Epoch 6/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0105
# Epoch 7/10
# 87/87 [==============================] - 3s 31ms/step - loss: 0.0103
# Epoch 8/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0070
# Epoch 9/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0065
# Epoch 10/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0070

# %%
stock_8 = "AVANTI.BO"
Stock_8 = yf.Ticker(stock_8)
hist = Stock_8.history(period="10mo")
data = hist.filter(['Close'])
dataset=data.values
new_df = hist.filter(['Close'])
last_60_days = new_df[-60:].values
training = math.ceil(len(dataset) * 0.7)
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
train_data = scaled_data[0:training,:]
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1],1))
x_train.shape
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (x_train.shape[1],1)))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train, y_train, batch_size = 1, epochs = 10)
last_60_days_scaled = scaler.transform(last_60_days)
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
pred_price_8 = model.predict(X_test)
pred_price_8 = scaler.inverse_transform(pred_price_8)

diff_8=pred_price_8-Stock_8.info['currentPrice']

earned_8 = ((1000 - Stock_8.info['currentPrice'])+pred_price_8)
# Out:
# Epoch 1/10
# 87/87 [==============================] - 6s 30ms/step - loss: 0.0443
# Epoch 2/10
# 87/87 [==============================] - 3s 31ms/step - loss: 0.0155
# Epoch 3/10
# 87/87 [==============================] - 3s 31ms/step - loss: 0.0110
# Epoch 4/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0090
# Epoch 5/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0118
# Epoch 6/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0100
# Epoch 7/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0074
# Epoch 8/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0079
# Epoch 9/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0072
# Epoch 10/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0070

# %%
#@title Default title text
stock_9 = "CIPLA.BO"
Stock_9 = yf.Ticker(stock_9)
hist = Stock_9.history(period="10mo")
data = hist.filter(['Close'])
dataset=data.values
new_df = hist.filter(['Close'])
last_60_days = new_df[-60:].values
training = math.ceil(len(dataset) * 0.7)
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
train_data = scaled_data[0:training,:]
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1],1))
x_train.shape
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (x_train.shape[1],1)))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train, y_train, batch_size = 1, epochs = 10)
last_60_days_scaled = scaler.transform(last_60_days)
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
pred_price_9 = model.predict(X_test)
pred_price_9 = scaler.inverse_transform(pred_price_9)

diff_9=pred_price_9-Stock_9.info['currentPrice']

earned_9 = ((1000 - Stock_9.info['currentPrice'])+pred_price_9)
# Out:
# Epoch 1/10
# 87/87 [==============================] - 6s 30ms/step - loss: 0.0363
# Epoch 2/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0270
# Epoch 3/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0200
# Epoch 4/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0173
# Epoch 5/10
# 87/87 [==============================] - 3s 31ms/step - loss: 0.0127
# Epoch 6/10
# 87/87 [==============================] - 3s 31ms/step - loss: 0.0112
# Epoch 7/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0109
# Epoch 8/10
# 87/87 [==============================] - 3s 31ms/step - loss: 0.0104
# Epoch 9/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0082
# Epoch 10/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0080

# %%
stock_10 = "GLENMARK.BO"
Stock_10 = yf.Ticker(stock_10)
hist = Stock_10.history(period="10mo")
data = hist.filter(['Close'])
dataset=data.values
new_df = hist.filter(['Close'])
last_60_days = new_df[-60:].values
training = math.ceil(len(dataset) * 0.7)
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)
train_data = scaled_data[0:training,:]
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)
x_train = np.reshape(x_train,(x_train.shape[0], x_train.shape[1],1))
x_train.shape
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape = (x_train.shape[1],1)))
model.add(LSTM(50, return_sequences = False))
model.add(Dense(25))
model.add(Dense(1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(x_train, y_train, batch_size = 1, epochs = 10)
last_60_days_scaled = scaler.transform(last_60_days)
X_test = []
X_test.append(last_60_days_scaled)
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
pred_price_10 = model.predict(X_test)
pred_price_10 = scaler.inverse_transform(pred_price_10)

diff_10=pred_price_10-Stock_10.info['currentPrice']

earned_10 = ((1000 - Stock_10.info['currentPrice'])+pred_price_10)
# Out:
# Epoch 1/10
# 87/87 [==============================] - 6s 30ms/step - loss: 0.0227
# Epoch 2/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0119
# Epoch 3/10
# 87/87 [==============================] - 3s 31ms/step - loss: 0.0094
# Epoch 4/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0109
# Epoch 5/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0080
# Epoch 6/10
# 87/87 [==============================] - 3s 29ms/step - loss: 0.0089
# Epoch 7/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0064
# Epoch 8/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0067
# Epoch 9/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0061
# Epoch 10/10
# 87/87 [==============================] - 3s 30ms/step - loss: 0.0052

# %%
print('''DISCLAIMER

This is just a game. For predicting actual values, different parameters has been used in a different model. Predictions in this model can vary from reality.''')

print('Total number of Stages in this round : 5')
print('')
print('Total Amount given for investment : Rs. 5000/-')
print('')
print("You will be given Rs.1000/- in every stage to invest in")
print('')
print('You will be given two options for investing, think and select one.') 
print('')
print('An algorithm has been applied which will give the end result.')
print('This algorithm is an Artificial Intelligence Algorithm which will help in predicting the future price')
print('')
print('EACH & EVERY THING IS BASED ON REAL-TIME DATA AS THE DATA IS DIRECTLY EXTRACTED FROM NSE/BSE WEBSITE. ONLY THE PREDICTIONS ARE MADE USING AN ALGORITHM')
print('')


print('''
                            ~~~ STAGE - 1 [Private Bank Sector] ~~~

                                            ⬇️

                                            🧍

                                            ⬇️
 
                                            🧍
 
                                           ''')

print("Q. Axis Bank Limited - Price : Rs.", Stock_1.info['currentPrice'],'| P. IndusInd Bank Limited - Price : Rs.',Stock_2.info['currentPrice'])

sel = input('Select your company in which you want to invest in for 1 day (intra-day Trading) : ')

print('')

if sel.lower() == 'q':
            print('''Excellent 😎 Decision
            You have invested : Rs.''',Stock_1.info['currentPrice']
            )
elif sel.lower() == 'p':
            print('''Excellent 😎 Decision
            You have invested : Rs.''',Stock_2.info['currentPrice']
            )
else:
            print(" ")

print('')
#-------------------------------------------------------------------------------------------------------
if sel.lower() == 'q':
            print('''⚖️ Balance Left ⚖️ : Rs.''',(1000-Stock_1.info['currentPrice']))
elif sel.lower() == 'p':
            print('''⚖️ Balance Left ⚖️ : Rs.''',(1000-Stock_2.info['currentPrice']))
else:
            print("Oops!")

print('')
#-------------------------------------------------------------------------------------------------------
if sel.lower() == 'q':
            print('''Now lets check what ANN-LSTM algorithm predicts :
            
            Collecting real-time stock data ----- 25%
            
            Structuring the ANN-LSTM Algorithm ----- 50%
            
            Arranging the data ---- 75%
            
            Making predictions ---- 100%
            
            SHOWING RESULTS : ''')
elif sel.lower() == 'p':
            print('''Now lets check what ANN-LSTM algorithm predicts :
            
            Collecting real-time stock data ----- 25%
            
            Structuring the ANN-LSTM Algorithm ----- 50%
            
            Arranging the data ---- 75%
            
            Making predictions ---- 100%
            
            SHOWING RESULTS : ''')
else:
            print("You have given the wrong option in your input")

print('')
 #-------------------------------------------------------------------------------------------------------           

if sel.lower() == 'q':
            print('''Yahoo Finance Ticker/Symbol for Axis Bank Limited is AXISBANK.BO
            Tomorrow(s) Predicted price for''', {stock_1} , 'will be :', pred_price_1)
elif sel.lower() == 'p':
            print('''Yahoo Finance Ticker/Symbol for IndusInd Bank Limited is INDUSINDBK.BO
            Tomorrow(s) Predicted price for''', {stock_2} , 'will be :', pred_price_2)
else:
            print("This STAGE is nullified for you")

print('')
# ------------------------------------------------------------------------------------------------------

if sel.lower() == 'q':
            print('''You Earned : Rs.''', diff_1,
            "| Now You Have : Rs.", earned_1)
elif sel.lower() == 'p':
            print('''You Earned : Rs.''', diff_2,
            "| Now You Have : Rs.",earned_2)
else:
            print("💀")

print('')
#-------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------
print('')

print('''
                        ~~~ STAGE - 2 [Technology Sector] ~~~

                                    ⬇️

                                    🧍

                                    ⬇️
 
                                    🧍
 
                                   ''')

print("S. Saksoft Ltd. - Price : Rs.", Stock_3.info['currentPrice'],'| W. Wipro Limited - Price : Rs.',Stock_4.info['currentPrice'])

sel_1 = input('Select your company in which you want to invest in for 1 day (intra-day Trading) : ')

print('')

if sel_1.lower() == 's':
            print('''Excellent 😎 Decision
            You have invested : Rs.''',Stock_3.info['currentPrice']
            )
elif sel_1.lower() == 'w':
            print('''Excellent 😎 Decision
            You have invested : Rs.''',Stock_4.info['currentPrice']
            )
else:
            print(" ")

print('')
#-------------------------------------------------------------------------------------------------------
if sel_1.lower() == 's':
            print('''⚖️ Balance Left ⚖️ : Rs.''',(1000-Stock_3.info['currentPrice']))
elif sel_1.lower() == 'w':
            print('''⚖️ Balance Left ⚖️ : Rs.''',(1000-Stock_4.info['currentPrice']))
else:
            print("Oops!")

print('')
#-------------------------------------------------------------------------------------------------------
if sel_1.lower() == 's':
            print('''Now lets check what ANN-LSTM algorithm predicts :
            
            Collecting real-time stock data ----- 25%
            
            Structuring the ANN-LSTM Algorithm ----- 50%
            
            Arranging the data ---- 75%
            
            Making predictions ---- 100%
            
            SHOWING RESULTS : ''')
elif sel_1.lower() == 'w':
            print('''Now lets check what ANN-LSTM algorithm predicts :
            
            Collecting real-time stock data ----- 25%
            
            Structuring the ANN-LSTM Algorithm ----- 50%
            
            Arranging the data ---- 75%
            
            Making predictions ---- 100%
            
            SHOWING RESULTS : ''')
else:
            print("You have given the wrong option in your input")

print('')
 #-------------------------------------------------------------------------------------------------------           

if sel_1.lower() == 's':
            print('''Yahoo Finance Ticker/Symbol for Saksoft Ltd. is SAKSOFT.BO
            Tomorrow(s) Predicted price for''', {stock_3} , 'will be :', pred_price_3)
elif sel_1.lower() == 'w':
            print('''Yahoo Finance Ticker/Symbol for Wipro Limited is WIPRO.BO
            Tomorrow(s) Predicted price for''', {stock_4} , 'will be :', pred_price_4)
else:
            print("This STAGE is nullified for you")

print('')
# ------------------------------------------------------------------------------------------------------

if sel_1.lower() == 's':
            print('''You Earned : Rs.''', diff_3,
            "| Now You Have : Rs.", earned_3)
elif sel_1.lower() == 'w':
            print('''You Earned : Rs.''', diff_4,
            "| Now You Have : Rs.",earned_4)
else:
            print("💀")

print('')
#-------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------

print('')

print('''
                                  ~~~ STAGE - 3 [Financial Sector] ~~~

                                                ⬇️

                                                🧍

                                                ⬇️
 
                                                🧍
 
                                               ''')

print("D. DHUNSERI INVESTMENTS LTD. - Price : Rs.", Stock_5.info['currentPrice'],'| A. Apollo Finvest (India) Limited - Price : Rs.',Stock_6.info['currentPrice'])

sel_2 = input('Select your company in which you want to invest in for 1 day (intra-day Trading) : ')

print('')

if sel_2.lower() == 'd':
            print('''Excellent 😎 Decision
            You have invested : Rs.''',Stock_5.info['currentPrice']
            )
elif sel_2.lower() == 'a':
            print('''Excellent 😎 Decision
            You have invested : Rs.''',Stock_6.info['currentPrice']
            )
else:
            print(" ")

print('')
#-------------------------------------------------------------------------------------------------------
if sel_2.lower() == 'd':
            print('''⚖️ Balance Left ⚖️ : Rs.''',(1000-Stock_5.info['currentPrice']))
elif sel_2.lower() == 'a':
            print('''⚖️ Balance Left ⚖️ : Rs.''',(1000-Stock_6.info['currentPrice']))
else:
            print("Oops!")

print('')
#-------------------------------------------------------------------------------------------------------
if sel_2.lower() == 'd':
            print('''Now lets check what ANN-LSTM algorithm predicts :
            
            Collecting real-time stock data ----- 25%
            
            Structuring the ANN-LSTM Algorithm ----- 50%
            
            Arranging the data ---- 75%
            
            Making predictions ---- 100%
            
            SHOWING RESULTS : ''')
elif sel_2.lower() == 'a':
            print('''Now lets check what ANN-LSTM algorithm predicts :
            
            Collecting real-time stock data ----- 25%
            
            Structuring the ANN-LSTM Algorithm ----- 50%
            
            Arranging the data ---- 75%
            
            Making predictions ---- 100%
            
            SHOWING RESULTS : ''')
else:
            print("You have given the wrong option in your input")

print('')
 #-------------------------------------------------------------------------------------------------------           

if sel_2.lower() == 'd':
            print('''Yahoo Finance Ticker/Symbol for DHUNSERI INVESTMENTS LTD. is DHUNINV.BO
            Tomorrow(s) Predicted price for''', {stock_5} , 'will be :', pred_price_5)
elif sel_2.lower() == 'a':
            print('''Yahoo Finance Ticker/Symbol for Apollo Finvest (India) Limited is APOLLOFI.BO
            Tomorrow(s) Predicted price for''', {stock_6} , 'will be :', pred_price_6)
else:
            print("This STAGE is nullified for you")

print('')
# ------------------------------------------------------------------------------------------------------

if sel_2.lower() == 'd':
            print('''You Earned : Rs.''', diff_5,
            "| Now You Have : Rs.", earned_5)
elif sel_2.lower() == 'a':
            print('''You Earned : Rs.''', diff_6,
            "| Now You Have : Rs.",earned_6)
else:
            print("💀")

print('')
#-------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------

print('')

print('''
                                 ~~~ STAGE - 4 [Agro Sector] ~~~

                                             ⬇️

                                             🧍

                                             ⬇️
 
                                             🧍
 
                                            ''')

print("Z. Godrej Agrovet Limited - Price : Rs.", Stock_7.info['currentPrice'],'| X. Avanti Feeds Limited - Price : Rs.',Stock_8.info['currentPrice'])

sel_3 = input('Select your company in which you want to invest in for 1 day (intra-day Trading) : ')

print('')

if sel_3.lower() == 'z':
            print('''Excellent 😎 Decision
            You have invested : Rs.''',Stock_7.info['currentPrice']
            )
elif sel_3.lower() == 'x':
            print('''Excellent 😎 Decision
            You have invested : Rs.''',Stock_8.info['currentPrice']
            )
else:
            print(" ")

print('')
#-------------------------------------------------------------------------------------------------------
if sel_3.lower() == 'z':
            print('''⚖️ Balance Left ⚖️ : Rs.''',(1000-Stock_7.info['currentPrice']))
elif sel_3.lower() == 'x':
            print('''⚖️ Balance Left ⚖️ : Rs.''',(1000-Stock_8.info['currentPrice']))
else:
            print("Oops!")

print('')
#-------------------------------------------------------------------------------------------------------
if sel_3.lower() == 'z':
            print('''Now lets check what ANN-LSTM algorithm predicts :
            
            Collecting real-time stock data ----- 25%
            
            Structuring the ANN-LSTM Algorithm ----- 50%
            
            Arranging the data ---- 75%
            
            Making predictions ---- 100%
            
            SHOWING RESULTS : ''')
elif sel_3.lower() == 'x':
            print('''Now lets check what ANN-LSTM algorithm predicts :
            
            Collecting real-time stock data ----- 25%
            
            Structuring the ANN-LSTM Algorithm ----- 50%
            
            Arranging the data ---- 75%
            
            Making predictions ---- 100%
            
            SHOWING RESULTS : ''')
else:
            print("You have given the wrong option in your input")

print('')
 #-------------------------------------------------------------------------------------------------------           

if sel_3.lower() == 'z':
            print('''Yahoo Finance Ticker/Symbol for DHUNSERI INVESTMENTS LTD. is DHUNINV.BO
            Tomorrow(s) Predicted price for''', {stock_7} , 'will be :', pred_price_7)
elif sel_3.lower() == 'x':
            print('''Yahoo Finance Ticker/Symbol for Apollo Finvest (India) Limited is APOLLOFI.BO
            Tomorrow(s) Predicted price for''', {stock_8} , 'will be :', pred_price_8)
else:
            print("This STAGE is nullified for you")

print('')
# ------------------------------------------------------------------------------------------------------

if sel_3.lower() == 'z':
            print('''You Earned : Rs.''', diff_7,
            "| Now You Have : Rs.", earned_7)
elif sel_3.lower() == 'x':
            print('''You Earned : Rs.''', diff_8,
            "| Now You Have : Rs.",earned_8)
else:
            print("💀")

print('')
#-------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------

print('''
                                 ~~~ STAGE - 5 [Pharma Sector] ~~~

                                             ⬇️

                                             🧍

                                             ⬇️
 
                                             🧍
 
                                            ''')

print("C. Cipla - Price : Rs.", Stock_9.info['currentPrice'],'| G. GLENMARK - Price : Rs.',Stock_10.info['currentPrice'])

sel_4 = input('Select your company in which you want to invest in for 1 day (intra-day Trading) : ')

print('')

if sel_4.lower() == 'c':
            print('''Excellent 😎 Decision
            You have invested : Rs.''',Stock_9.info['currentPrice']
            )
elif sel_4.lower() == 'g':
            print('''Excellent 😎 Decision
            You have invested : Rs.''',Stock_10.info['currentPrice']
            )
else:
            print(" ")

print('')
#-------------------------------------------------------------------------------------------------------
if sel_4.lower() == 'c':
            print('''⚖️ Balance Left ⚖️ : Rs.''',(1000-Stock_9.info['currentPrice']))
elif sel_4.lower() == 'g':
            print('''⚖️ Balance Left ⚖️ : Rs.''',(1000-Stock_10.info['currentPrice']))
else:
            print("Oops!")

print('')
#-------------------------------------------------------------------------------------------------------
if sel_4.lower() == 'c':
            print('''Now lets check what ANN-LSTM algorithm predicts :
            
            Collecting real-time stock data ----- 25%
            
            Structuring the ANN-LSTM Algorithm ----- 50%
            
            Arranging the data ---- 75%
            
            Making predictions ---- 100%
            
            SHOWING RESULTS : ''')
elif sel_4.lower() == 'g':
            print('''Now lets check what ANN-LSTM algorithm predicts :
            
            Collecting real-time stock data ----- 25%
            
            Structuring the ANN-LSTM Algorithm ----- 50%
            
            Arranging the data ---- 75%
            
            Making predictions ---- 100%
            
            SHOWING RESULTS : ''')
else:
            print("You have given the wrong option in your input")

print('')
 #-------------------------------------------------------------------------------------------------------           

if sel_4.lower() == 'c':
            print('''Yahoo Finance Ticker/Symbol for DHUNSERI INVESTMENTS LTD. is DHUNINV.BO
            Tomorrow(s) Predicted price for''', {stock_9} , 'will be :', pred_price_9)
elif sel_4.lower() == 'g':
            print('''Yahoo Finance Ticker/Symbol for Apollo Finvest (India) Limited is APOLLOFI.BO
            Tomorrow(s) Predicted price for''', {stock_10} , 'will be :', pred_price_10)
else:
            print("This STAGE is nullified for you")

print('')
# ------------------------------------------------------------------------------------------------------

if sel_4.lower() == 'c':
            print('''You Earned : Rs.''', diff_9,
            "| Now You Have : Rs.", earned_9)
elif sel_4.lower() == 'g':
            print('''You Earned : Rs.''', diff_10,
            "| Now You Have : Rs.",earned_10)
else:
            print("💀")

print('')
#-------------------------------------------------------------------------------------------------------
#-------------------------------------------------------------------------------------------------------

print('''
I hope you liked this game.

I request you to kindly give the Feedback so that I can improve myself.

https://forms.office.com/r/gxTRmrrjt9

Thank you for playing this Investment Game.

Follow me on Medium for such Amazing Content !
aryanbajaj13.medium.com

''' )
# Out:
# DISCLAIMER
#
# This is just a game. For predicting actual values, different parameters has been used in a different model. Predictions in this model can vary from reality.
# Total number of Stages in this round : 5
#
# Total Amount given for investment : Rs. 5000/-
#
# You will be given Rs.1000/- in every stage to invest in
#
# You will be given two options for investing, think and select one.
#
# An algorithm has been applied which will give the end result.
# This algorithm is an Artificial Intelligence Algorithm which will help in predicting the future price
#
# EACH & EVERY THING IS BASED ON REAL-TIME DATA AS THE DATA IS DIRECTLY EXTRACTED FROM NSE/BSE WEBSITE. ONLY THE PREDICTIONS ARE MADE USING AN ALGORITHM
#
#
#                             ~~~ STAGE - 1 [Private Bank Sector] ~~~
#
#                                             ⬇️
#
#                                             🧍
#
#                                             ⬇️
#
#                                             🧍
# ...
